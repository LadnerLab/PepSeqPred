# %%
import pandas as pd
from pathlib import Path

path = Path("../localdata/fulldesign_2019-02-27_wGBKsw.metadata")

# %%
with open(path, "r") as meta:
    content = meta.read()

content[:1000]

# %%
df = pd.read_csv(path, sep="\t")
display(df.head())
display(df.info())
