# %%
from pathlib import Path
import pandas as pd
import numpy as np

VW_PREFIX = "VW_"

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
z_path = Path("../../../PV1 Data/SHERC_combined_wSB_4-24-24_Z-HDI95_avg.tsv").resolve()
z_df = pd.read_csv(z_path, sep="\t")
display(z_df.head())
# Out:
#   Sequence name    VW_001    VW_002    VW_003    VW_004    VW_006    VW_007  \
# 0    PV1_120184  0.676192  2.609729 -0.085760  0.848174 -0.159656  1.363783
# 1    PV1_079687 -0.506422 -0.305140 -0.356729 -0.412638  0.110855 -0.349799
# 2    PV1_232363 -0.370618 -0.091842 -0.066678  0.071725  1.439856 -0.800894
# 3    PV1_170274 -0.162534  0.388937  0.237627  1.253256  3.678245  0.823017
# 4    PV1_202108 -0.192092 -0.078002 -0.172140 -0.099731  0.298264 -0.541937
#
#      VW_008    VW_009    VW_010    VW_011    VW_012    VW_013    VW_014  \
# 0  1.105352 -1.158855  0.786950 -0.109514  0.377156  0.163014  0.550770
# 1 -1.135790 -1.235670  0.009699  0.785919  0.955614 -0.633779 -0.014028
# 2  0.027334 -0.155257 -0.754262  2.555048  0.300497 -0.608313 -0.419885
# 3  1.028029  0.338581  1.507745  2.728657  1.894530 -0.232864  1.042501
# 4 -0.723582  1.267090 -0.569766 -0.443379 -0.573047 -0.413969 -0.544181
#
#      VW_015    VW_016    VW_017    VW_018    VW_019    VW_020    VW_021  \
# ...

# %%
def apply_threshold(df, zscore_cutoff=10.0, count_cutoff=100):
    # assuming df passed in full
    subject_cols = [col for col in df.columns if col.startswith(VW_PREFIX)]

    subjects = df.loc[:, subject_cols].apply(pd.to_numeric, errors="coerce")
    counts = (subjects.to_numpy() >= zscore_cutoff).sum(axis=1)
    
    return df.assign(**{"Contains epitope": (counts >= count_cutoff).astype("int8")})

z_df_cleaned = apply_threshold(z_df, zscore_cutoff=5.0, count_cutoff=20)
display(z_df_cleaned.head())
# Out:
#   Sequence name    VW_001    VW_002    VW_003    VW_004    VW_006    VW_007  \
# 0    PV1_120184  0.676192  2.609729 -0.085760  0.848174 -0.159656  1.363783
# 1    PV1_079687 -0.506422 -0.305140 -0.356729 -0.412638  0.110855 -0.349799
# 2    PV1_232363 -0.370618 -0.091842 -0.066678  0.071725  1.439856 -0.800894
# 3    PV1_170274 -0.162534  0.388937  0.237627  1.253256  3.678245  0.823017
# 4    PV1_202108 -0.192092 -0.078002 -0.172140 -0.099731  0.298264 -0.541937
#
#      VW_008    VW_009    VW_010    VW_011    VW_012    VW_013    VW_014  \
# 0  1.105352 -1.158855  0.786950 -0.109514  0.377156  0.163014  0.550770
# 1 -1.135790 -1.235670  0.009699  0.785919  0.955614 -0.633779 -0.014028
# 2  0.027334 -0.155257 -0.754262  2.555048  0.300497 -0.608313 -0.419885
# 3  1.028029  0.338581  1.507745  2.728657  1.894530 -0.232864  1.042501
# 4 -0.723582  1.267090 -0.569766 -0.443379 -0.573047 -0.413969 -0.544181
#
#      VW_015    VW_016    VW_017    VW_018    VW_019    VW_020    VW_021  \
# ...

# %%
z_df_cleaned.loc[z_df_cleaned["Contains epitope"].eq(1)].head()
# Out:
#     Sequence name     VW_001     VW_002      VW_003      VW_004      VW_006  \
# 9      PV1_184327   1.991156  26.260905   -0.302569   -0.231978    1.944425
# 45     PV1_072467   6.059315  25.839748    5.156216   -1.011673   12.916800
# 47     PV1_068820  15.510640  53.281900  159.819100  124.671916  105.662050
# 66     PV1_052250   0.042442  -0.025338   -0.171172    0.146845   -0.641359
# 103    PV1_067142  -0.529262  -0.308835   -0.328572   40.866799    0.657703
#
#         VW_007     VW_008    VW_009      VW_010      VW_011    VW_012  \
# 9     1.438579  11.003500 -1.334170    0.131589    0.666400 -0.114462
# 45   14.920950   5.672655  0.046254   24.219000   -0.646506 -0.654488
# 47   49.655500  29.251350  3.615880  162.139500  133.631500  2.268073
# 66   -0.428125  -0.396546 -0.028890    1.159363    2.253005 -0.182554
# 103   6.346115   1.270715 -0.177205    0.563914    0.171314  0.860367
#
#          VW_013     VW_014     VW_015     VW_016     VW_017     VW_018  \
# ...

# %%
z_df_cleaned_2 = apply_threshold(z_df, zscore_cutoff=10.0, count_cutoff=20)
z_df_cleaned_2.loc[z_df_cleaned_2["Contains epitope"].eq(1)].head()
# Out:
#     Sequence name      VW_001     VW_002      VW_003      VW_004      VW_006  \
# 45     PV1_072467    6.059315  25.839748    5.156216   -1.011673   12.916800
# 47     PV1_068820   15.510640  53.281900  159.819100  124.671916  105.662050
# 150    PV1_051660  621.654000   0.897856  241.400000   28.993290   -0.475973
# 154    PV1_058293  108.731850  64.681900   -0.141018    0.229556    0.646751
# 168    PV1_081270   -0.078023   4.148580   21.077809   -0.478294   20.481600
#
#         VW_007     VW_008    VW_009      VW_010      VW_011    VW_012  \
# 45   14.920950   5.672655  0.046254   24.219000   -0.646506 -0.654488
# 47   49.655500  29.251350  3.615880  162.139500  133.631500  2.268073
# 150  -0.238482  -0.420341  0.956820    0.796790   -0.190638  0.331817
# 154  -0.504220   1.700306 -0.552211    4.571120    3.272825 -0.732752
# 168   3.539150  35.753050  1.153757    6.842975   15.051100  7.572225
#
#          VW_013     VW_014     VW_015     VW_016     VW_017     VW_018  \
# ...
